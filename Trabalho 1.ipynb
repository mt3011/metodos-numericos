# %% [markdown]
# ## Questão 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def y1(x):
    return x**3 + x**2 - 10*x + 10

def y2(x):
    return np.sin(x)/x

def dy1(x):
    return 3*x**2 + 2*x -10

def dy2(x):
    return (x*np.cos(x) - np.sin(x))/x

def dy3(x):
    return "nada ainda"

# %%
def dy(f,Xmin, Xmax, dx):
    steps = round((Xmax - Xmin)/dx)

    yaxis = np.zeros(steps)
    xaxis = np.linspace(Xmin, Xmax, steps)

    for i in range(steps): yaxis[i] = f(xaxis[i])
        
    return xaxis, yaxis

# %%
x, y = dy(y1,-5,5,0.1)
plt.grid(linewidth = 0.5)
plt.plot(x,y)

# %%
x1, y1 = dy(y2,-50,50,0.1)
plt.grid(linewidth = 0.5)
plt.plot(x1,y1)

# %%
# Out:
# array([-5.        , -4.47368421, -3.94736842, -3.42105263, -2.89473684,
#        -2.36842105, -1.84210526, -1.31578947, -0.78947368, -0.26315789,
#         0.26315789,  0.78947368,  1.31578947,  1.84210526,  2.36842105,
#         2.89473684,  3.42105263,  3.94736842,  4.47368421,  5.        ])
